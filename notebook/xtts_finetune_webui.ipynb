# %% [markdown]
# <a href="https://colab.research.google.com/github/ryul82/CoinExchange/blob/master/notebook/xtts_finetune_webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the *xtts*-finetune-webui gradio gui!
#
# This webui is a slightly modified copy of the official webui for finetune xtts.
#
# If you are looking for an option for normal XTTS use look here https://github.com/daswer123/xtts-webui

# %%
# @title 🛠️ Install requirments
#!DEBIAN_FRONTEND=noninteractive
# !sudo apt-get update # && sudo apt-get -y upgrade
# !sudo apt-get -y install libegl1
# !sudo apt-get -y install libopengl0
# !sudo apt-get -y install libxcb-cursor0
# !pip install -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt
# !pip install gradio==4.44.1
# !pip install fastapi==0.103.1
# !pip install pydantic==2.3.0
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,105 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,438 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,665 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,606 kB]
# Fetched 15.2 MB in 2s (6,335 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libegl1 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopengl0 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libxcb-image0 libxcb-render-util0 libxcb-util1
# The following NEW packages will be installed:
#   libxcb-cursor0 libxcb-image0 libxcb-render-util0 libxcb-util1
# 0 upgraded, 4 newly installed, 0 to remove and 52 not upgraded.
# Need to get 43.8 kB of archives.
# After this operation, 178 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Fetched 43.8 kB in 0s (158 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libxcb-util1:amd64.
# (Reading database ... 123623 files and directories currently installed.)
# Preparing to unpack .../libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# Collecting faster_whisper==1.0.3 (from -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading faster_whisper-1.0.3-py3-none-any.whl.metadata (15 kB)
# Collecting gradio==5.1.0 (from -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading gradio-5.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: spacy==3.7.5 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (3.7.5)
# Collecting coqui-tts==0.24.2 (from coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading coqui_tts-0.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting cutlet (from -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 6))
#   Downloading cutlet-0.4.0.tar.gz (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 13.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fugashi[unidic-lite] (from -r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 7))
#   Downloading fugashi-1.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting av<13,>=11.0 (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading av-12.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting ctranslate2<5,>=4.0 (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading ctranslate2-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (0.24.7)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (0.19.1)
# Collecting onnxruntime<2,>=1.14 (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading onnxruntime-1.20.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (3.7.1)
# Collecting fastapi<1.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.4.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading gradio_client-1.4.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (0.27.2)
# Collecting huggingface-hub>=0.13 (from faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (3.1.4)
# Collecting markupsafe~=2.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (3.10.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2.9.2)
# Collecting pydub (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading python_multipart-0.0.17-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading ruff-0.7.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.0.11)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.5.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.5.0+cu121)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: librosa>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.10.2.post1)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (7.4.0)
# Collecting anyascii>=0.3.0 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2024.10.0)
# Collecting pysbd>=0.3.4 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.8.0)
# Collecting coqui-tts-trainer==0.1.4 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading coqui_tts_trainer-0.1.4-py3-none-any.whl.metadata (8.4 kB)
# Collecting coqpit>=0.0.16 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting gruut>=2.4.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut-2.4.0.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.8.0)
# Collecting transformers<4.43.0,>=4.42.0 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading transformers-4.42.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.8 MB/s eta 0:00:00
# Collecting encodec>=0.1.1 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 66.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting num2words>=0.5.11 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from coqui-tts-trainer==0.1.4->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts-trainer==0.1.4->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.17.0)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting jaconv (from cutlet->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 6))
#   Downloading jaconv-0.4.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mojimoji (from cutlet->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 6))
#   Downloading mojimoji-0.0.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting unidic-lite (from fugashi[unidic-lite]->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 7))
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (1.2.2)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi<1.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2))
#   Downloading starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.10.10)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.16.0)
# Collecting dateparser~=1.1.1 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut_lang_en-2.0.1.tar.gz (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 64.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: networkx>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.4.2)
# Collecting python-crfsuite~=0.9.7 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading python_crfsuite-0.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut_lang_de-2.0.1.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 45.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 16.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (4.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.8.2)
# Collecting docopt>=0.6.2 (from num2words>=0.5.11->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.17.1)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]<3.8,>=3->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading SudachiPy-0.6.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting sudachidict-core>=20211220 (from spacy[ja]<3.8,>=3->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading SudachiDict_core-20241021-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (0.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper==1.0.3->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.43.0,>=4.42.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.43.0,>=4.42.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.4.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (7.0.5)
# Collecting mecab-python3>=1.0.2 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading mecab_python3-1.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting hangul-romanize>=0.1.0 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting jamo>=0.4.1 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting g2pkk>=0.1.1 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading g2pkk-0.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting bangla>=0.0.2 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading bangla-0.0.2-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting bnnumerizer>=0.0.2 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bnunicodenormalizer>=0.1.0 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jieba>=0.42.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.42.1)
# Collecting pypinyin>=0.40.0 (from coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4))
#   Downloading pypinyin-0.53.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (4.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (5.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from g2pkk>=0.1.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (4.3.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.1.0->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.10.1->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy==3.7.5->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer==0.1.4->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer==0.1.4->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer==0.1.4->coqui-tts==0.24.2->coqui-tts[languages]==0.24.2->-r https://raw.githubusercontent.com/daswer123/xtts-finetune-webui/main/requirements.txt (line 4)) (3.7)
# ...
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.1-py3-none-any.whl size=18498313 sha256=9ca2a20ed963d39c3ccdabbe9bd0898af7d43eceade154eaa90d4e46dbb13f6e
#   Stored in directory: /root/.cache/pip/wheels/83/80/5f/775b357ae61d7cb68793327c7470d848715cbc60bb373af8dd
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.1-py3-none-any.whl size=15326857 sha256=b49722a4e5f8fa4b5cc60c1320781b70f422d48e66d65fa9ce82164fa925d3a3
#   Stored in directory: /root/.cache/pip/wheels/64/8d/b7/d484d224facd899ed188e00374f25dd3f19d1a3f53da6517bd
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-2.0.1-py3-none-any.whl size=32173928 sha256=2ecf208de9bcdd5f46517227b4bdc5c7f41256cd0aa37fb5be4743d8b6594074
#   Stored in directory: /root/.cache/pip/wheels/ab/bd/96/5ddde14e8e6932a96f12c5ab5de62b619d39e2507d7daf5188
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968766 sha256=e9359542f2bd8661fb65a5e01c8aa48a681aed52ff7cc255639b2b5f7fb8ad67
#   Stored in directory: /root/.cache/pip/wheels/db/21/be/d0436e3f1cf9bf38b9bb9b4a476399c77a1ab19f7172b45e19
# Successfully built cutlet encodec gruut unidic-lite jaconv bnnumerizer docopt gruut-ipa gruut_lang_de gruut_lang_en gruut_lang_es gruut_lang_fr
# Installing collected packages: unidic-lite, sudachipy, pydub, mecab-python3, jamo, jaconv, hangul-romanize, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, docopt, bnunicodenormalizer, bnnumerizer, bangla, websockets, uvicorn, tomlkit, sudachidict-core, semantic-version, ruff, python-multipart, python-crfsuite, pysbd, pypinyin, num2words, mojimoji, markupsafe, jsonlines, humanfriendly, gruut-ipa, fugashi, ffmpy, ctranslate2, coqpit, av, anyascii, aiofiles, starlette, huggingface-hub, g2pkk, dateparser, cutlet, coloredlogs, onnxruntime, gruut, gradio-client, fastapi, transformers, gradio, faster_whisper, coqui-tts-trainer, encodec, coqui-tts
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.7
#     Uninstalling huggingface-hub-0.24.7:
#       Successfully uninstalled huggingface-hub-0.24.7
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# Successfully installed aiofiles-23.2.1 anyascii-0.3.2 av-12.3.0 bangla-0.0.2 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.7 coloredlogs-15.0.1 coqpit-0.0.17 coqui-tts-0.24.2 coqui-tts-trainer-0.1.4 ctranslate2-4.5.0 cutlet-0.4.0 dateparser-1.1.8 docopt-0.6.2 encodec-0.1.1 fastapi-0.115.4 faster_whisper-1.0.3 ffmpy-0.4.0 fugashi-1.3.3 g2pkk-0.1.2 gradio-5.1.0 gradio-client-1.4.0 gruut-2.4.0 gruut-ipa-0.13.0 gruut_lang_de-2.0.1 gruut_lang_en-2.0.1 gruut_lang_es-2.0.1 gruut_lang_fr-2.0.2 hangul-romanize-0.1.0 huggingface-hub-0.26.2 humanfriendly-10.0 jaconv-0.4.0 jamo-0.4.1 jsonlines-1.2.0 markupsafe-2.1.5 mecab-python3-1.0.10 mojimoji-0.0.13 num2words-0.5.13 onnxruntime-1.20.0 pydub-0.25.1 pypinyin-0.53.0 pysbd-0.3.4 python-crfsuite-0.9.11 python-multipart-0.0.17 ruff-0.7.2 semantic-version-2.10.0 starlette-0.41.2 sudachidict-core-20241021 sudachipy-0.6.8 tomlkit-0.12.0 transformers-4.42.4 unidic-lite-1.0.8 uvicorn-0.32.0 websockets-12.0
# Collecting gradio==4.44.1
#   Downloading gradio-4.44.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (3.7.1)
# Requirement already satisfied: fastapi<1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.115.4)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.4.0)
# Collecting gradio-client==1.3.0 (from gradio==4.44.1)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.26.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (3.8.0)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (3.10.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (2.9.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.0.17)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.7.2)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (2.2.3)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.44.1) (0.32.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.3.0->gradio==4.44.1) (2024.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.3.0->gradio==4.44.1) (12.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==4.44.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==4.44.1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio==4.44.1) (1.2.2)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from fastapi<1.0->gradio==4.44.1) (0.41.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.44.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.44.1) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.44.1) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.44.1) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.44.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.44.1) (4.66.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.44.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.44.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.44.1) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.44.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.44.1) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.44.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.44.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.44.1) (13.9.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.44.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.44.1) (3.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.1) (0.1.2)
# Downloading gradio-4.44.1-py3-none-any.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 78.2 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 25.6 MB/s eta 0:00:00
# Installing collected packages: gradio-client, gradio
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.4.0
#     Uninstalling gradio_client-1.4.0:
#       Successfully uninstalled gradio_client-1.4.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.1.0
#     Uninstalling gradio-5.1.0:
#       Successfully uninstalled gradio-5.1.0
# Successfully installed gradio-4.44.1 gradio-client-1.3.0
# Collecting fastapi==0.103.1
#   Downloading fastapi-0.103.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.103.1) (3.7.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.103.1) (2.9.2)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.103.1)
#   Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.103.1) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.103.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.103.1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.103.1) (1.2.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.103.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.103.1) (2.23.4)
# Downloading fastapi-0.103.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 3.9 MB/s eta 0:00:00
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: starlette, fastapi
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.41.2
#     Uninstalling starlette-0.41.2:
#       Successfully uninstalled starlette-0.41.2
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.4
#     Uninstalling fastapi-0.115.4:
#       Successfully uninstalled fastapi-0.115.4
# Successfully installed fastapi-0.103.1 starlette-0.27.0
# Collecting pydantic==2.3.0
#   Downloading pydantic-2.3.0-py3-none-any.whl.metadata (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.3.0) (0.7.0)
# Collecting pydantic-core==2.6.3 (from pydantic==2.3.0)
#   Downloading pydantic_core-2.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.3.0) (4.12.2)
# Downloading pydantic-2.3.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 20.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 55.4 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 2.3.0 which is incompatible.
# langchain 0.3.4 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 2.3.0 which is incompatible.
# langchain-core 0.3.13 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 2.3.0 which is incompatible.
# Successfully installed pydantic-2.3.0 pydantic-core-2.6.3

# %%
# @title 🚀 Run interface
# %cd /content/
# !git clone https://github.com/DrewThomasson/xtts-finetune-webui.git
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share

# %%
import shutil
import requests
import os
from tqdm import tqdm  # Progress bar library

# Define the paths
finetune_dir = '/content/xtts-finetune-webui/finetune_models/ready'  # @param {type:"string"}
dataset_dir = '/content/xtts-finetune-webui/finetune_models/dataset'  # @param {type:"string"}

# Create a temporary directory to collect both folders before zipping
temp_dir = "/content/temp_finetune_dataset"
os.makedirs(temp_dir, exist_ok=True)

# Copy both directories into the temporary directory with a progress bar
def copy_with_progress(src, dst):
    total_files = sum(len(files) for _, _, files in os.walk(src))
    with tqdm(total=total_files, desc=f"Copying {os.path.basename(src)}") as pbar:
        for root, _, files in os.walk(src):
            rel_path = os.path.relpath(root, src)
            target_path = os.path.join(dst, rel_path)
            os.makedirs(target_path, exist_ok=True)
            for file in files:
                shutil.copy(os.path.join(root, file), target_path)
                pbar.update(1)

copy_with_progress(finetune_dir, os.path.join(temp_dir, "ready"))
copy_with_progress(dataset_dir, os.path.join(temp_dir, "dataset"))

# Create a zip file of the combined directories with progress
zip_filename = "finetune_and_dataset.zip"
with tqdm(total=100, desc="Zipping files") as pbar:
    shutil.make_archive("finetune_and_dataset", 'zip', root_dir=temp_dir)
    pbar.update(100)

# Define a function to stream the upload with a progress bar
def upload_with_progress(file_path, url):
    file_size = os.path.getsize(file_path)
    with open(file_path, 'rb') as f, tqdm(
        total=file_size, unit='B', unit_scale=True, desc="Uploading"
    ) as progress:
        response = requests.post(
            url,
            files={"file": (file_path, f)},
            stream=True,
            headers={"Connection": "keep-alive"},
        )
        # Update the progress bar as chunks are sent
        for chunk in response.iter_content(chunk_size=4096):
            if chunk:
                progress.update(len(chunk))
    return response

# Upload the zip file to file.io with a progress bar
response = upload_with_progress(zip_filename, "https://file.io/?expires=1d")

# Parse the response and display the download link
if response.status_code == 200:
    download_link = response.json().get('link', 'Error: No link found.')
    print(f"Your file is ready: {download_link}")
else:
    print(f"Failed to upload: {response.status_code} - {response.text}")
